# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn import decomposition
from random import sample
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn import preprocessing

# %%
datos = pd.read_excel('wine.xlsx')
datos
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1513            6.2             0.600         0.08             2.0      0.090
# 1514            5.9             0.550         0.10             2.2      0.062
# 1515            6.3             0.510         0.13             2.3      0.076
# 1516            5.9             0.645         0.12             2.0      0.075
# 1517            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Distribución
sns.countplot(datos['quality'])

# %%
#BOXPLOT de cada caracteristica con la variable diagnosis
for i in ['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']:
    boxplot = datos.boxplot(column=i, by='quality', fontsize=10,figsize=(10,5),)
    plt.show()

# %%
# Correlación
correlacion_estudiantes_base=datos.corr()
correlacion_estudiantes_base.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col2 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col3 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col4 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d7260b86_a29c_11ea_887e_9c7bef13acbbrow0_col6 {
#             background-color:  #5b7ae5;
#             color:  #000000;
# ...

# %%
data=datos.drop(['volatile acidity','density','alcohol'],axis=1)
data
# Out:
#       fixed acidity  citric acid  residual sugar  chlorides  \
# 0               7.4         0.00             1.9      0.076
# 1               7.8         0.00             2.6      0.098
# 2               7.8         0.04             2.3      0.092
# 3              11.2         0.56             1.9      0.075
# 4               7.4         0.00             1.9      0.076
# ...             ...          ...             ...        ...
# 1513            6.2         0.08             2.0      0.090
# 1514            5.9         0.10             2.2      0.062
# 1515            6.3         0.13             2.3      0.076
# 1516            5.9         0.12             2.0      0.075
# 1517            6.0         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide    pH  sulphates  quality
# 0                    11.0                  34.0  3.51       0.56        5
# 1                    25.0                  67.0  3.20       0.68        5
# ...

# %%
x = data.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df = pd.DataFrame(x_scaled)
df.columns = ['fixed aciditu', 'citric acid',' residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide', 'pH', 'sulphates', 'quality']
datos = df.drop(['quality'], axis=1)
columna_quality = pd.DataFrame(data['quality'])
dato_normalizado = pd.concat([datos,columna_quality], axis=1)
dato_normalizado.head()
# Out:
#    fixed aciditu  citric acid   residual sugar  chlorides  \
# 0       0.241071     0.000000         0.068493   0.106845
# 1       0.276786     0.000000         0.116438   0.143573
# 2       0.276786     0.050633         0.095890   0.133556
# 3       0.580357     0.708861         0.068493   0.105175
# 4       0.241071     0.000000         0.068493   0.106845
#
#    free sulfur dioxide  total sulfur dioxide        pH  sulphates  quality
# 0             0.140845              0.098940  0.565217   0.118012        5
# 1             0.338028              0.215548  0.295652   0.192547        5
# 2             0.197183              0.169611  0.347826   0.173913        5
# 3             0.225352              0.190813  0.260870   0.130435        6
# 4             0.140845              0.098940  0.565217   0.118012        5

# %%
X=dato_normalizado.iloc[:,0:8] ## Corresponde a las caracteristicas sin la variable de llegada diagnosis
X
# Out:
#       fixed aciditu  citric acid   residual sugar  chlorides  \
# 0          0.241071     0.000000         0.068493   0.106845
# 1          0.276786     0.000000         0.116438   0.143573
# 2          0.276786     0.050633         0.095890   0.133556
# 3          0.580357     0.708861         0.068493   0.105175
# 4          0.241071     0.000000         0.068493   0.106845
# ...             ...          ...              ...        ...
# 1513       0.133929     0.101266         0.075342   0.130217
# 1514       0.107143     0.126582         0.089041   0.083472
# 1515       0.142857     0.164557         0.095890   0.106845
# 1516       0.107143     0.151899         0.075342   0.105175
# 1517       0.116071     0.594937         0.184932   0.091820
#
#       free sulfur dioxide  total sulfur dioxide        pH  sulphates
# 0                0.140845              0.098940  0.565217   0.118012
# 1                0.338028              0.215548  0.295652   0.192547
# ...

# %%
Y = dato_normalizado.iloc[:,8:9]
Y
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1513        5
# 1514        6
# 1515        6
# 1516        5
# 1517        6
#
# [1518 rows x 1 columns]

# %%
# PCA 
pca = decomposition.PCA(n_components=8)
X1 = pca.fit_transform(X)

# %%
X_FSEX =pd.DataFrame({'PCA1': X1[:,0], 'PCA2': X1[:,1],'PCA3': X1[:,2], 'PCA4': X1[:,3],'PCA5': X1[:,4],'PCA6': X1[:,5],'PCA7': X1[:,6],'PCA8': X1[:,7]})
X_FSEX
# Out:
#           PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0    -0.382042 -0.125520 -0.020076 -0.020297  0.007410 -0.051316 -0.038601
# 1    -0.281251  0.107964 -0.227428  0.094617  0.002068  0.009779  0.016775
# 2    -0.249747 -0.028532 -0.155026  0.063722  0.001704  0.030213 -0.021250
# 3     0.442331  0.038967 -0.041814 -0.101280 -0.094911 -0.028182 -0.021959
# 4    -0.382042 -0.125520 -0.020076 -0.020297  0.007410 -0.051316 -0.038601
# ...        ...       ...       ...       ...       ...       ...       ...
# 1513 -0.349457  0.152803  0.030515 -0.002757 -0.039393 -0.058955  0.119626
# 1514 -0.356993  0.257333  0.105413  0.052138 -0.022487 -0.142327  0.091330
# 1515 -0.270051  0.127266  0.062955  0.067059 -0.005365 -0.069398  0.080437
# 1516 -0.345870  0.164682  0.151617  0.027390 -0.020887 -0.115306  0.074566
# 1517  0.086552  0.073002  0.277721 -0.061502  0.039418  0.090008  0.062815
#
#           PCA8
# 0     0.064583
# 1    -0.024415
# 2    -0.003940
# ...

# %%
X_con_F = pd.concat([X_FSEX, X], axis=1)
X_con_F
# Out:
#           PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0    -0.382042 -0.125520 -0.020076 -0.020297  0.007410 -0.051316 -0.038601
# 1    -0.281251  0.107964 -0.227428  0.094617  0.002068  0.009779  0.016775
# 2    -0.249747 -0.028532 -0.155026  0.063722  0.001704  0.030213 -0.021250
# 3     0.442331  0.038967 -0.041814 -0.101280 -0.094911 -0.028182 -0.021959
# 4    -0.382042 -0.125520 -0.020076 -0.020297  0.007410 -0.051316 -0.038601
# ...        ...       ...       ...       ...       ...       ...       ...
# 1513 -0.349457  0.152803  0.030515 -0.002757 -0.039393 -0.058955  0.119626
# 1514 -0.356993  0.257333  0.105413  0.052138 -0.022487 -0.142327  0.091330
# 1515 -0.270051  0.127266  0.062955  0.067059 -0.005365 -0.069398  0.080437
# 1516 -0.345870  0.164682  0.151617  0.027390 -0.020887 -0.115306  0.074566
# 1517  0.086552  0.073002  0.277721 -0.061502  0.039418  0.090008  0.062815
#
# ...

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.svm import SVC
# Sequential Forward Selection(sfs)
sfs = SFS(MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,)),
           k_features=8,
           forward=True,
           floating=False,
           scoring = 'r2',
           cv = 0)

# %%
# Sequential Forward Selection(sfs)
sbs = SFS(MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,)),
           k_features=8,
           forward=False,
           floating=False,
           scoring = 'r2',
           cv = 0)

# %%
#FSEs-sfs
sfs.fit (X, Y) 
sfs.k_feature_names_
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#FSEs-sbs
sbs.fit (X, Y) 
sbs.k_feature_names_
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('fixed aciditu',
#  'citric acid',
#  ' residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'pH',
#  'sulphates')

# %%
#FSXs-sfs
sfs.fit (X_FSEX, Y) 
sfs.k_feature_names_
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#FSXs-sbs
sbs.fit (X_FSEX, Y) 
sbs.k_feature_names_
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ('PCA1', 'PCA2', 'PCA3', 'PCA4', 'PCA5', 'PCA6', 'PCA7', 'PCA8')

# %%
#FSXs:FSEs-sbs
sbs.fit (X_con_F, Y) 
sbs.k_feature_names_
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
#FSXs:FSEs-sfs
sfs.fit (X_con_F, Y) 
sfs.k_feature_names_
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
import copy
Xsfs = copy.copy(X_con_F)
Xsbs = copy.copy(X_con_F)
Xsbs = Xsbs.drop(columns=['PCA1','PCA4','PCA6','PCA7','pH',' residual sugar','chlorides','free sulfur dioxide'], axis=1)
Xsfs = Xsfs.drop(columns=['PCA1','PCA2','PCA3','PCA8','free sulfur dioxide','sulphates','total sulfur dioxide',' residual sugar'], axis=1)
# 'radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave_points_mean','symmetry_mean','radius_se','perimeter_se','area_se','compactness_se','concavity_se','concave_points_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave_points_worst','symmetry_worst','fractal_dimension_worst'

# %%
X_test,X_train,Y_test,Y_train=train_test_split(X,Y,test_size=0.2,random_state=40) # fse
X_FSEX_test,X_FSEX_train,Ye_test,Ye_train=train_test_split(X_FSEX,Y,test_size=0.2,random_state=40) #fsx
X_con_F_test,X_con_F_train,yef_test,yef_train=train_test_split(X_con_F,Y,test_size=0.2,random_state=40) #fsx:fse
Xsbs_test,Xsbs_train,ysbs_test,ysbs_train=train_test_split(Xsbs,Y,test_size=0.2,random_state=40) # (fse:fsx))s(sbs)
Xsfs_test,Xsfs_train,ysfs_test,ysfs_train=train_test_split(Xsfs,Y,test_size=0.2,random_state=40) # (fse:fsx)s(sfs)

# %%
cls1=MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,))
cls2=MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,))
cls3=MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,))
cls4=MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,))
cls5=MLPClassifier(activation='logistic',solver='lbfgs',alpha=1e-05,hidden_layer_sizes=(30,))

# %%
cls1.fit(X_train,Y_train)
cls3.fit(X_FSEX_train.abs(),Ye_train)
cls4.fit(X_con_F_train.abs(),yef_train)
cls4.fit(Xsbs_train.abs(),ysbs_train)
cls5.fit(Xsfs_train.abs(),ysfs_train)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:934: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
from sklearn import metrics
predict_test1 = cls1.predict(X_test)
predict_test2 = cls2.predict(X_FSEX_test)
predict_test3 = cls3.predict(X_con_F_test)
predict_test4 = cls4.predict(Xsbs_test)
predict_test5 = cls5.predict(Xsfs_test)
#Evaluar
acc_n1 = metrics.accuracy_score(predict_test1,Y_test)
acc_n2 = metrics.accuracy_score(predict_test2,Ye_test)
acc_n3 = metrics.accuracy_score(predict_test3,yef_test)
acc_n4 = metrics.accuracy_score(predict_test4,ysbs_train)
acc_n5 = metrics.accuracy_score(predict_test5,ysfs_train)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-46-918d41580c2f> in <module>
#       1 from sklearn import metrics
#       2 predict_test1 = cls1.predict(X_test)
# ----> 3 predict_test2 = cls2.predict(X_FSEX_test)
#       4 predict_test3 = cls3.predict(X_con_F_test)
#       5 predict_test4 = cls4.predict(Xsbs_test)
#
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in predict(self, X)
#     968             The predicted classes.
#     969         """
# --> 970         check_is_fitted(self)
#     971         y_pred = self._predict(X)
#     972
#
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     965
#     966     if not attrs:
# --> 967         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     968
#     969
#
# ...

# %%
print("Accuracy sin normalización: {:.1f}".format(acc_n1*100))
# Out:
# Accuracy sin normalización: 52.4
